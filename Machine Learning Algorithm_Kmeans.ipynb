# %%
pwd
# Out:
# '/Users/surajpawar/Desktop/Machine learning algorithms_sklearn'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ["area", "perimeter", "compactness", "length", "width", "asymmetry", "groove", "class"]
df = pd.read_csv("/Users/surajpawar/Desktop/Machine learning algorithms_sklearn/seeds_dataset.txt", names = cols)

# %%
df.head()
# Out:
#                                                 area  perimeter  compactness  \
# 0  15.26\t14.84\t0.871\t5.763\t3.312\t2.221\t5.22\t1        NaN          NaN
# 1  14.88\t14.57\t0.8811\t5.554\t3.333\t1.018\t4.9...        NaN          NaN
# 2  14.29\t14.09\t0.905\t5.291\t3.337\t2.699\t4.82...        NaN          NaN
# 3  13.84\t13.94\t0.8955\t5.324\t3.379\t2.259\t4.8...        NaN          NaN
# 4  16.14\t14.99\t0.9034\t5.658\t3.562\t1.355\t5.1...        NaN          NaN
#
#    length  width  asymmetry  groove  class
# 0     NaN    NaN        NaN     NaN    NaN
# 1     NaN    NaN        NaN     NaN    NaN
# 2     NaN    NaN        NaN     NaN    NaN
# 3     NaN    NaN        NaN     NaN    NaN
# 4     NaN    NaN        NaN     NaN    NaN

# %%
cols = ["area", "perimeter", "compactness", "length", "width", "asymmetry", "groove", "class"]
df = pd.read_csv("/Users/surajpawar/Desktop/Machine learning algorithms_sklearn/seeds_dataset.txt", names = cols, sep="\s+")

# %%
df.head()
# Out:
#     area  perimeter  compactness  length  width  asymmetry  groove  class
# 0  15.26      14.84       0.8710   5.763  3.312      2.221   5.220      1
# 1  14.88      14.57       0.8811   5.554  3.333      1.018   4.956      1
# 2  14.29      14.09       0.9050   5.291  3.337      2.699   4.825      1
# 3  13.84      13.94       0.8955   5.324  3.379      2.259   4.805      1
# 4  16.14      14.99       0.9034   5.658  3.562      1.355   5.175      1

# %%
for i in range(len(cols)-1):
    for j in range(len(cols)-1):
        x_label = cols[i]
        y_label = cols[j]
        sns.scatterplot(x=x_label, y=y_label, data=df, hue="class")
        plt.show()

# %%
from sklearn.cluster import KMeans

# %%
x = "perimeter"
y = "asymmetry"
X = df[[x, y]].values

# %%
kmeans = KMeans(n_clusters = 3).fit(X)
# Out:
# /Users/surajpawar/Desktop/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clusters = kmeans.labels_

# %%
cluster_df = pd.DataFrame(np.hstack((X, clusters.reshape(-1,1))), columns = [x, y, "class"])

# %%
#kmeans classes
sns.scatterplot(x=x, y=y, hue="class", data=cluster_df)
plt.plot()
# Out:
# []

# %%
#original classes
sns.scatterplot(x=x, y=y, hue="class", data=df)
plt.plot()
# Out:
# []

# %%
X = df[cols[:-1]].values

# %%
kmeans = KMeans(n_clusters=3).fit(X)
cluster_df = pd.DataFrame(np.hstack((X, clusters.reshape(-1,1))), columns = df.columns)
# Out:
# /Users/surajpawar/Desktop/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
sns.scatterplot(x=x, y=y, hue="class", data=cluster_df)
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x=x, y=y, hue="class", data=df)
plt.plot()
# Out:
# []

# %%
X = df[cols[:-1]].values

# %%
kmeans = KMeans(n_clusters=3).fit(X)
cluster_df = pd.DataFrame(np.hstack((X, kmeans.labels_.reshape(-1,1))), columns = df.columns)
# Out:
# /Users/surajpawar/Desktop/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
sns.scatterplot(x=x, y=y, hue="class", data=cluster_df)
plt.plot()
# Out:
# []

# %%
sns.scatterplot(x=x, y=y, hue="class", data=df)
plt.plot()
# Out:
# []
